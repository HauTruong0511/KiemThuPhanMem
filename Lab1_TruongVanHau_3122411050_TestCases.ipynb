# %%
# !g++ "/Users/vanhien/Documents/Kiem Thu/Lab1_TruongVanHau_3122411050_TestCases.cpp" -o BaiTap1

# %%
# !./BaiTap1
# Out:
# Test 1: a=-2, b=-3, c=5
#   => 2 solution(s): 1 -1
# -----------------------
# Test 2: a=-1, b=5, c=-4
#   => 4 solution(s): 1 -1 2 -2
# -----------------------
# Test 3: a=-3, b=-4, c=-4
#   => No solution
# -----------------------
# Test 4: a=-4, b=2, c=5
#   => 2 solution(s): 1.18137 -1.18137
# -----------------------
# Test 5: a=-2, b=2, c=2
#   => 2 solution(s): 1.27202 -1.27202
# -----------------------
# Test 6: a=-4, b=-5, c=5
#   => 2 solution(s): 0.809857 -0.809857
# -----------------------
# Test 7: a=-1, b=-1, c=-3
#   => No solution
# -----------------------
# Test 8: a=4, b=-5, c=5
#   => No solution
# -----------------------
# Test 9: a=1, b=4, c=-3
#   => 2 solution(s): 0.803587 -0.803587
# -----------------------
# Test 10: a=-1, b=0, c=5
#   => 2 solution(s): 1.49535 -1.49535
# -----------------------
